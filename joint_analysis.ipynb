# %% [markdown]
# # KELT-1b eclipse - all visits

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rc('figure', figsize=(13,4))

# %%
from src.kelt1 import read_data, EclipseLPF

# %% [markdown]
# ## Initialise the LPF

# %%
visit = None

# %%
time, flux, cov = read_data(visit)
lpf = EclipseLPF('kelt-1', 'cheops', time, flux, covariates=cov, tref=floor(time[0][0]))
lpf.print_parameters(1)
# Out:
#   0 |G| tc             N(μ = 2458764.31647, σ = 0.00018)        [    -inf ..      inf]
#   1 |G| p              N(μ = 1.2174928, σ = 1.7e-06)            [    0.00 ..      inf]
#   2 |G| rho            N(μ = 0.58, σ = 0.05)                    [    0.00 ..      inf]
#   3 |G| b              N(μ = 0.195, σ = 0.05)                   [    0.00 ..     1.00]
#   4 |G| secw           N(μ = 0.0, σ = 0.0001)                   [   -1.00 ..     1.00]
#   5 |G| sesw           N(μ = 0.0, σ = 0.0001)                   [   -1.00 ..     1.00]
#   6 |P| k2             N(μ = 0.005935, σ = 4.468e-05)           [    0.00 ..      inf]
#   7 |P| fr_cheops      U(a = 0.0, b = 0.2)                      [    0.00 ..     1.00]
#   8 |L| wn_loge_0      U(a = -4, b = 0)                         [    -inf ..      inf]
#   9 |L| lm_i__0        N(μ = 1.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  10 |L| lm_s__0_1      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  11 |L| lm_s__0_2      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  12 |L| lm_s__0_3      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  13 |L| lm_s__0_4      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  14 |L| lm_s__0_5      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  15 |L| lm_s__0_6      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  16 |L| lm_s__0_7      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  17 |L| lm_s__0_8      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  18 |L| lm_s__0_9      N(μ = 0.0, σ = 0.0006666551846110111)    [    -inf ..      inf]
#  19 |L| lm_i__0        N(μ = 1.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  20 |L| lm_s__0_1      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  21 |L| lm_s__0_2      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  22 |L| lm_s__0_3      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  23 |L| lm_s__0_4      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  24 |L| lm_s__0_5      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  25 |L| lm_s__0_6      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  26 |L| lm_s__0_7      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  27 |L| lm_s__0_8      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  28 |L| lm_s__0_9      N(μ = 0.0, σ = 0.0006577008621444929)    [    -inf ..      inf]
#  29 |L| lm_i__0        N(μ = 1.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  30 |L| lm_s__0_1      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  31 |L| lm_s__0_2      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  32 |L| lm_s__0_3      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  33 |L| lm_s__0_4      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  34 |L| lm_s__0_5      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  35 |L| lm_s__0_6      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  36 |L| lm_s__0_7      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  37 |L| lm_s__0_8      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  38 |L| lm_s__0_9      N(μ = 0.0, σ = 0.0005511624578132436)    [    -inf ..      inf]
#  39 |L| lm_i__0        N(μ = 1.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  40 |L| lm_s__0_1      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  41 |L| lm_s__0_2      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  42 |L| lm_s__0_3      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  43 |L| lm_s__0_4      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  44 |L| lm_s__0_5      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  45 |L| lm_s__0_6      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  46 |L| lm_s__0_7      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  47 |L| lm_s__0_8      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]
#  48 |L| lm_s__0_9      N(μ = 0.0, σ = 0.0005728210481571515)    [    -inf ..      inf]

# %% [markdown]
# ## Find the global posterior mode

# %%
lpf.optimize_global(3500, npop=100)
# Out:
# HBox(children=(HTML(value='Global optimisation'), FloatProgress(value=0.0, max=1500.0), HTML(value='')))

# %%
lpf.plot_folded_eclipse_model();

# %%
lpf.plot_flux_model();

# %% [markdown]
# ## Sample the posterior using MCMC

# %%
lpf.sample_mcmc(500, 20, repeats=10)
# Out:
# HBox(children=(HTML(value='MCMC sampling'), FloatProgress(value=0.0, max=10.0), HTML(value='')))
# HBox(children=(HTML(value='Run 1/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 2/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 3/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 4/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 5/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 6/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 7/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 8/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 9/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))
# HBox(children=(HTML(value='Run 10/10'), FloatProgress(value=0.0, max=500.0), HTML(value='')))

# %%
lpf.sample_mcmc(5000, 20, repeats=1)
# Out:
# HBox(children=(HTML(value='MCMC sampling'), FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(HTML(value='Run 1/1'), FloatProgress(value=0.0, max=5000.0), HTML(value='')))

# %%
fig = lpf.plot_posteriors(truncate=False, nsamples=300);
fig.savefig('kelt_1_joint_posteriors.pdf')

# %%
fig = lpf.plot_folded_eclipse_model('mcmc')
fig.savefig('kelt_1_joint_model_posterior.pdf')

# %%
lpf.plot_flux_model('mcmc');

# %% [markdown]
# ---
#
# <center>&copy;2020 Hannu Parviainen</center>
