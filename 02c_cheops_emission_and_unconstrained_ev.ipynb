# %% [markdown]
# # CHEOPS secondary eclipse modelling
# ## Case a: Mixed reflection and thermal emission
#
# **Author:** Hannu Parviainen<br>
# **Last edited:** 2.8.2021
#
# While the TESS photometry coveres the whole KELT-1b phase, the CHEOPS photometry covers only the near vicinity of the secondary eclipse. This means that we can't estimate the ellipsoidal variations or Doppler boosting independently for the CHEOPS passband.

# %%
# %run src/init_threading_for_multiprocessing.py

# %%
# %pylab inline
rc('figure', figsize=(13,4))
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
from multiprocessing import Pool
from src import CHEOPSLPF

# %%
lpf = CHEOPSLPF('c')

# %%
def lnposterior(pv):
    return squeeze(lpf.lnposterior(pv))

pool = Pool(processes=16)

# %%
lpf.ps
# Out:
# [  0 |G| tc             N(μ = 2455914.1623686487, σ = 0.00036075967534218267) [    -inf ..      inf],
#    1 |G| p              N(μ = 1.217494211307908, σ = 1.8333872888315754e-07) [    0.00 ..      inf],
#    2 |G| rho            N(μ = 0.567348412839003, σ = 0.03998774043069618) [    0.00 ..      inf],
#    3 |G| b              N(μ = 0.3385059906839748, σ = 0.07468033088440729) [    0.00 ..     1.00],
#    4 |G| secw           N(μ = 0.0, σ = 1e-06)                    [   -1.00 ..     1.00],
#    5 |G| sesw           N(μ = 0.0, σ = 1e-06)                    [   -1.00 ..     1.00],
#    6 |P| k2             N(μ = 0.005813305131183557, σ = 7.117523186891932e-05) [    0.00 ..      inf],
#    7 |G| oev            N(μ = 0.02550211198092813, σ = 0.03626265168082909) [    -inf ..      inf],
#    8 |G| aev_cheops     U(a = 0.0, b = 0.001)                    [    0.00 ..      inf],
#    9 |G| adb_cheops     N(μ = 6.3e-05, σ = 6.4e-06)              [    0.00 ..      inf],
#   10 |G| log10_ted_cheops U(a = -3.0, b = 0.0)                     [    -inf ..      inf],
#   11 |G| log10_ten_cheops N(μ = -5.0, σ = 0.01)                    [    -inf ..      inf],
#   12 |G| teo_cheops     N(μ = 0.0, σ = 1e-07)                    [    -inf ..      inf],
#   13 |G| ag_cheops      N(μ = 0.0001, σ = 1e-06)                 [    0.00 ..     1.00],
#   14 |P| q1_cheops      N(μ = 0.5, σ = 1e-06)                    [    0.00 ..     1.00],
#   15 |P| q2_cheops      N(μ = 0.5, σ = 1e-06)                    [    0.00 ..     1.00],
#   16 |L| wn_loge_0      U(a = -4, b = 0)                         [    -inf ..      inf],
#   17 |L| lm_i__0        L(μ = 1.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   18 |L| lm_s__0_1      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   19 |L| lm_s__0_2      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   20 |L| lm_s__0_3      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   21 |L| lm_s__0_4      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   22 |L| lm_s__0_5      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   23 |L| lm_s__0_6      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   24 |L| lm_s__0_7      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   25 |L| lm_s__0_8      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   26 |L| lm_s__0_9      L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   27 |L| lm_s__0_10     L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   28 |L| lm_s__0_11     L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   29 |L| lm_s__0_12     L(μ = 0.0, MAD = 0.0016188891415126424)  [    -inf ..      inf],
#   30 |L| lm_i__0        L(μ = 1.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   31 |L| lm_s__0_1      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   32 |L| lm_s__0_2      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   33 |L| lm_s__0_3      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   34 |L| lm_s__0_4      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   35 |L| lm_s__0_5      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   36 |L| lm_s__0_6      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   37 |L| lm_s__0_7      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   38 |L| lm_s__0_8      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   39 |L| lm_s__0_9      L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   40 |L| lm_s__0_10     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   41 |L| lm_s__0_11     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   42 |L| lm_s__0_12     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   43 |L| lm_s__0_13     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   44 |L| lm_s__0_14     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   45 |L| lm_s__0_15     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   46 |L| lm_s__0_16     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   47 |L| lm_s__0_17     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   48 |L| lm_s__0_18     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   49 |L| lm_s__0_19     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   50 |L| lm_s__0_20     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   51 |L| lm_s__0_21     L(μ = 0.0, MAD = 0.0015980595824562672)  [    -inf ..      inf],
#   52 |L| lm_i__0        L(μ = 1.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   53 |L| lm_s__0_1      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   54 |L| lm_s__0_2      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   55 |L| lm_s__0_3      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   56 |L| lm_s__0_4      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   57 |L| lm_s__0_5      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   58 |L| lm_s__0_6      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   59 |L| lm_s__0_7      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   60 |L| lm_s__0_8      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   61 |L| lm_s__0_9      L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   62 |L| lm_s__0_10     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   63 |L| lm_s__0_11     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   64 |L| lm_s__0_12     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   65 |L| lm_s__0_13     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   66 |L| lm_s__0_14     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   67 |L| lm_s__0_15     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   68 |L| lm_s__0_16     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   69 |L| lm_s__0_17     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   70 |L| lm_s__0_18     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   71 |L| lm_s__0_19     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   72 |L| lm_s__0_20     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   73 |L| lm_s__0_21     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   74 |L| lm_s__0_22     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   75 |L| lm_s__0_23     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   76 |L| lm_s__0_24     L(μ = 0.0, MAD = 0.0014388658480380945)  [    -inf ..      inf],
#   77 |L| lm_i__0        L(μ = 1.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   78 |L| lm_s__0_1      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   79 |L| lm_s__0_2      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   80 |L| lm_s__0_3      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   81 |L| lm_s__0_4      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   82 |L| lm_s__0_5      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   83 |L| lm_s__0_6      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   84 |L| lm_s__0_7      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   85 |L| lm_s__0_8      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   86 |L| lm_s__0_9      L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   87 |L| lm_s__0_10     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   88 |L| lm_s__0_11     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   89 |L| lm_s__0_12     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   90 |L| lm_s__0_13     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   91 |L| lm_s__0_14     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   92 |L| lm_s__0_15     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   93 |L| lm_s__0_16     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   94 |L| lm_s__0_17     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   95 |L| lm_s__0_18     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   96 |L| lm_s__0_19     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   97 |L| lm_s__0_20     L(μ = 0.0, MAD = 0.001371954416735278)   [    -inf ..      inf],
#   98 |L| lm_i__0        L(μ = 1.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#   99 |L| lm_s__0_1      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  100 |L| lm_s__0_2      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  101 |L| lm_s__0_3      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  102 |L| lm_s__0_4      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  103 |L| lm_s__0_5      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  104 |L| lm_s__0_6      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  105 |L| lm_s__0_7      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  106 |L| lm_s__0_8      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  107 |L| lm_s__0_9      L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  108 |L| lm_s__0_10     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  109 |L| lm_s__0_11     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  110 |L| lm_s__0_12     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  111 |L| lm_s__0_13     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  112 |L| lm_s__0_14     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  113 |L| lm_s__0_15     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  114 |L| lm_s__0_16     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  115 |L| lm_s__0_17     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  116 |L| lm_s__0_18     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  117 |L| lm_s__0_19     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  118 |L| lm_s__0_20     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  119 |L| lm_s__0_21     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  120 |L| lm_s__0_22     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  121 |L| lm_s__0_23     L(μ = 0.0, MAD = 0.0016157992072557011)  [    -inf ..      inf],
#  122 |L| lm_i__0        L(μ = 1.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  123 |L| lm_s__0_1      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  124 |L| lm_s__0_2      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  125 |L| lm_s__0_3      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  126 |L| lm_s__0_4      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  127 |L| lm_s__0_5      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  128 |L| lm_s__0_6      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  129 |L| lm_s__0_7      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  130 |L| lm_s__0_8      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  131 |L| lm_s__0_9      L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  132 |L| lm_s__0_10     L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  133 |L| lm_s__0_11     L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  134 |L| lm_s__0_12     L(μ = 0.0, MAD = 0.0014760415218066066)  [    -inf ..      inf],
#  135 |L| lm_i__0        L(μ = 1.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  136 |L| lm_s__0_1      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  137 |L| lm_s__0_2      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  138 |L| lm_s__0_3      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  139 |L| lm_s__0_4      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  140 |L| lm_s__0_5      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  141 |L| lm_s__0_6      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  142 |L| lm_s__0_7      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  143 |L| lm_s__0_8      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  144 |L| lm_s__0_9      L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  145 |L| lm_s__0_10     L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  146 |L| lm_s__0_11     L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  147 |L| lm_s__0_12     L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  148 |L| lm_s__0_13     L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  149 |L| lm_s__0_14     L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  150 |L| lm_s__0_15     L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  151 |L| lm_s__0_16     L(μ = 0.0, MAD = 0.0018084845196708328)  [    -inf ..      inf],
#  152 |L| lm_i__0        L(μ = 1.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  153 |L| lm_s__0_1      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  154 |L| lm_s__0_2      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  155 |L| lm_s__0_3      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  156 |L| lm_s__0_4      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  157 |L| lm_s__0_5      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  158 |L| lm_s__0_6      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  159 |L| lm_s__0_7      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  160 |L| lm_s__0_8      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  161 |L| lm_s__0_9      L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  162 |L| lm_s__0_10     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  163 |L| lm_s__0_11     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  164 |L| lm_s__0_12     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  165 |L| lm_s__0_13     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  166 |L| lm_s__0_14     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  167 |L| lm_s__0_15     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  168 |L| lm_s__0_16     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  169 |L| lm_s__0_17     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  170 |L| lm_s__0_18     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  171 |L| lm_s__0_19     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  172 |L| lm_s__0_20     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  173 |L| lm_s__0_21     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  174 |L| lm_s__0_22     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  175 |L| lm_s__0_23     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  176 |L| lm_s__0_24     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  177 |L| lm_s__0_25     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  178 |L| lm_s__0_26     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  179 |L| lm_s__0_27     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf],
#  180 |L| lm_s__0_28     L(μ = 0.0, MAD = 0.0020544322958330717)  [    -inf ..      inf]]

# %% [markdown]
# ## Find the global posterior mode

# %%
lpf.optimize_global(150, npop=400, pool=pool, vectorize=False, lnpost=lnposterior)
# Out:
# Global optimisation:   0%|          | 0/150 [00:00<?, ?it/s]

# %%
lpf.optimize_global(15000, npop=400, pool=pool, vectorize=False, lnpost=lnposterior)
# Out:
# Global optimisation:   0%|          | 0/15000 [00:00<?, ?it/s]

# %%
lpf.plot_folded_light_curve();

# %% [markdown]
# ## Sample the posterior using MCMC

# %%
lpf.sample_mcmc(5000, 100, repeats=10, save=True, pool=pool, vectorize=False, lnpost=lnposterior)
# Out:
# MCMC sampling:   0%|          | 0/10 [00:00<?, ?it/s]
# Run 1/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 2/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 3/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 4/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 5/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 6/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 7/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 8/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 9/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.
# Run 10/10:   0%|          | 0/5000 [00:00<?, ?it/s]
# Could not save the samples in fits format.

# %%
df = lpf.posterior_samples()

# %%
df.log10_ted_cheops.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
(10**df.log10_ted_cheops).hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
fig = lpf.plot_posteriors(truncate=False, nsamples=300);
fig.savefig(f'kelt_1_tw_logistic_joint_posteriors.png')

# %%
fig = lpf.plot_folded_eclipse_model('mcmc')
#fig.savefig(f'kelt_1_tw_logistic_joint_model_posterior.png')

# %%
from pytransit.lpf.tesslpf import downsample_time
from pytransit.utils.misc import fold

# %%
df = lpf.posterior_samples(derived_parameters=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_250739/337366290.py in <module>
# ----> 1 df = lpf.posterior_samples(derived_parameters=False)
#
# ~/soft/anaconda/lib/python3.8/site-packages/PyTransit-2.5.13-py3.8.egg/pytransit/lpf/lpf.py in posterior_samples(self, burn, thin, derived_parameters)
#     546
#     547     def posterior_samples(self, burn: int = 0, thin: int = 1, derived_parameters: bool = True):
# --> 548         df = super().posterior_samples(burn=burn, thin=thin)
#     549         if derived_parameters:
#     550             for k2c in df.columns[self._sl_k2]:
#
# ~/soft/anaconda/lib/python3.8/site-packages/PyTransit-2.5.13-py3.8.egg/pytransit/lpf/logposteriorfunction.py in posterior_samples(self, burn, thin)
#     198
#     199     def posterior_samples(self, burn: int = 0, thin: int = 1):
# --> 200         fc = self.sampler.chain[:, burn::thin, :].reshape([-1, len(self.ps)])
#     201         df = pd.DataFrame(fc, columns=self.ps.names)
#     202         return df
#
# AttributeError: 'NoneType' object has no attribute 'chain'

# %%
phase = (fold(lpf.timea, df.p.mean(), df.tc.mean()) - 0.5)*df.p.mean()

# %%
sids = argsort(phase)

# %%
oflux = lpf.ofluxa / lpf.baseline(df.median().values)

# %%
pb, fb, eb = downsample_time(phase[sids], oflux[sids], 0.025)

# %%
errorbar(pb, fb, eb, fmt='.')
plot(phase[sids], lpf.transit_model(df.median())[sids], 'k')

# %%
df.lm_i__0
# Out:
#         lm_i__0   lm_i__0   lm_i__0   lm_i__0   lm_i__0   lm_i__0   lm_i__0  \
# 0      1.000320  1.000357  1.000311  1.000371  1.000356  1.000430  1.000297
# 1      1.000321  1.000375  1.000312  1.000376  1.000366  1.000420  1.000303
# 2      1.000313  1.000351  1.000288  1.000367  1.000348  1.000425  1.000287
# 3      1.000306  1.000352  1.000297  1.000367  1.000356  1.000422  1.000292
# 4      1.000305  1.000349  1.000294  1.000359  1.000341  1.000420  1.000289
# ...         ...       ...       ...       ...       ...       ...       ...
# 59995  1.000324  1.000336  1.000331  1.000297  1.000238  1.000426  1.000247
# 59996  1.000357  1.000339  1.000352  1.000313  1.000268  1.000424  1.000277
# 59997  1.000360  1.000349  1.000356  1.000314  1.000269  1.000429  1.000284
# 59998  1.000347  1.000342  1.000343  1.000312  1.000267  1.000423  1.000280
# 59999  1.000349  1.000351  1.000346  1.000319  1.000267  1.000419  1.000282
#
#         lm_i__0
# 0      1.000282
# 1      1.000249
# 2      1.000243
# 3      1.000245
# 4      1.000235
# ...         ...
# 59995  1.000276
# 59996  1.000288
# 59997  1.000299
# 59998  1.000299
# 59999  1.000304
#
# [60000 rows x 8 columns]

# %%
df.shape[1]
# Out:
# 179

# %%
icols = [i for i in range(df.shape[1]) if 'lm_i__' in df.columns[i]]

# %%
df.iloc[:,icols[0]].hist()
# Out:
# <AxesSubplot:>

# %%
df.iloc[:,icols[1]].hist()
# Out:
# <AxesSubplot:>

# %%
df = lpf.posterior_samples(derived_parameters=False)

fig, ax = subplots(figsize=(13,6))
bplot(df.iloc[:,10:])
ax.set_ylim(-0.0003, 0.0003)
setp(ax, xlabel='PSF component')
fig.tight_layout()

# %%
lpf.save()

# %% [markdown]
# ---
#
# <center>&copy;2020 Hannu Parviainen</center>
