# %% [markdown]
# # 1 Modelling the external data
# ## Case c) Thermal emission only, free ellipsoidal variation
#
# **Author:** Hannu Parviainen<br>
# **Last edited:** 21.11.2021
#
# Here we model the KELT-1 light curves observed with TESS (Beatty20, XX20), LBT (Beatty), and Spitzer (Beatty2019, Beatty2017) using a full phase curve model that includes the transit, secondary eclipse, thermal emission, reflection, ellipsoidal variations and Doppler boosting.
#
# The model is implemented by `src.priordatalpf.JointLPF`, which inherits all its functionality from `pytransit.lpf.PhaseCurveLPF`.
#
# In this base case we don't constrain the geometric albedo or the planet's day-side flux ratio (we do this in the later cases). These two parameters should be linearly correlated since they are the main parameters affecting the eclipse depth, but it is useful to see their joint posterior.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from corner import corner
from src import ExternalDataLPF, read_mcmc

# %%
lpf = ExternalDataLPF('d')

# %%
how_to_start = 'continue'

if how_to_start is 'start_from_scratch':
    lpf.optimize_global(45000, 300)
    lpf.sample_mcmc(50, thin=10, repeats=1, save=False)
    
elif how_to_start is 'start_from_scenario_a':
    lpf.optimize_global(1, 300)
    df = read_mcmc('results/01a_ext_emission_and theoretical_ev.nc')
    sids = permutation(df.values.shape[0])[:lpf.de.n_pop]
    starting_population = df.values[sids, :-1].copy()
    for p in lpf.ps:
        if 'ag' in p.name:
            starting_population[:,p.pid] = uniform(0.0, 0.5, 300)
    lpf.sample_mcmc(50, thin=10, repeats=1, save=False, population=starting_population)
    
elif how_to_start is 'continue':
    lpf.optimize_global(1, 300)
    df = read_mcmc('results/01d_ext_emission_and_reflection_and_theoretical_ev.nc')
    sids = permutation(df.values.shape[0])[:lpf.de.n_pop]
    starting_population = df.values[sids, :-1].copy()
    lpf.sample_mcmc(50, thin=10, repeats=1, save=False, population=starting_population)
    
else:
    raise NotImplementedError

# %%
lpf.sample_mcmc(5000, thin=50, repeats=8, save=True)
# Out:
# MCMC sampling:   0%|          | 0/8 [00:00<?, ?it/s]
# Run 1/8:   0%|          | 0/5000 [00:00<?, ?it/s]
# Run 2/8:   0%|          | 0/5000 [00:00<?, ?it/s]
# Run 3/8:   0%|          | 0/5000 [00:00<?, ?it/s]
# Run 4/8:   0%|          | 0/5000 [00:00<?, ?it/s]
# Run 5/8:   0%|          | 0/5000 [00:00<?, ?it/s]
# Run 6/8:   0%|          | 0/5000 [00:00<?, ?it/s]

# %%
lpf.sample_mcmc(15000, thin=50, repeats=2, save=True)
# Out:
# MCMC sampling:   0%|          | 0/2 [00:00<?, ?it/s]
# Run 1/2:   0%|          | 0/15000 [00:00<?, ?it/s]
# Run 2/2:   0%|          | 0/15000 [00:00<?, ?it/s]

# %%
df = lpf.posterior_samples(derived_parameters=False)

# %%
lpf.ps
# Out:
# [  0 |G| tc             N(μ = 2455914.1628, σ = 0.01)            [    -inf ..      inf],
#    1 |G| p              N(μ = 1.217513, σ = 4.5e-05)             [    0.00 ..      inf],
#    2 |G| rho            N(μ = 0.6, σ = 0.075)                    [    0.00 ..      inf],
#    3 |G| b              U(a = 0.0, b = 1.0)                      [    0.00 ..     1.00],
#    4 |G| secw           N(μ = 0.0, σ = 1e-06)                    [   -1.00 ..     1.00],
#    5 |G| sesw           N(μ = 0.0, σ = 1e-06)                    [   -1.00 ..     1.00],
#    6 |P| k2             N(μ = 0.078, σ = 0.005)                  [    0.00 ..      inf],
#    7 |G| oev            N(μ = 0.0, σ = 1e-07)                    [    -inf ..      inf],
#    8 |G| aev_TESS       N(μ = 0.000434, σ = 2.4999999999999998e-05) [    0.00 ..      inf],
#    9 |G| adb_TESS       N(μ = 4.1e-05, σ = 4.2e-06)              [    0.00 ..      inf],
#   10 |G| ted_TESS       U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   11 |G| ten_TESS       U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   12 |G| teo_TESS       N(μ = 0.0, σ = 0.17453292519943295)      [    -inf ..      inf],
#   13 |G| ag_TESS        U(a = 0.0, b = 2.0)                      [    0.00 ..     1.00],
#   14 |G| aev_H          N(μ = 0.000352, σ = 1.9999999999999998e-05) [    0.00 ..      inf],
#   15 |G| adb_H          N(μ = 2.5e-05, σ = 2.6e-06)              [    0.00 ..      inf],
#   16 |G| ted_H          U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   17 |G| ten_H          U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   18 |G| teo_H          N(μ = 0.0, σ = 1e-05)                    [    -inf ..      inf],
#   19 |G| ag_H           U(a = 0.0, b = 2.0)                      [    0.00 ..     1.00],
#   20 |G| aev_Ks         N(μ = 0.000347, σ = 1.9999999999999998e-05) [    0.00 ..      inf],
#   21 |G| adb_Ks         N(μ = 1.9e-05, σ = 1.84e-06)             [    0.00 ..      inf],
#   22 |G| ted_Ks         U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   23 |G| ten_Ks         U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   24 |G| teo_Ks         N(μ = 0.0, σ = 1e-05)                    [    -inf ..      inf],
#   25 |G| ag_Ks          U(a = 0.0, b = 2.0)                      [    0.00 ..     1.00],
#   26 |G| aev_36um       N(μ = 0.000338, σ = 1.9999999999999998e-05) [    0.00 ..      inf],
#   27 |G| adb_36um       N(μ = 1.7e-05, σ = 1.66e-06)             [    0.00 ..      inf],
#   28 |G| ted_36um       U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   29 |G| ten_36um       U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   30 |G| teo_36um       N(μ = 0.0, σ = 0.17453292519943295)      [    -inf ..      inf],
#   31 |G| ag_36um        U(a = 0.0, b = 2.0)                      [    0.00 ..     1.00],
#   32 |G| aev_45um       N(μ = 0.000337, σ = 1.9999999999999998e-05) [    0.00 ..      inf],
#   33 |G| adb_45um       N(μ = 1.6e-05, σ = 1.58e-06)             [    0.00 ..      inf],
#   34 |G| ted_45um       U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   35 |G| ten_45um       U(a = 0.0, b = 0.5)                      [    -inf ..      inf],
#   36 |G| teo_45um       N(μ = 0.0, σ = 0.17453292519943295)      [    -inf ..      inf],
#   37 |G| ag_45um        U(a = 0.0, b = 2.0)                      [    0.00 ..     1.00],
#   38 |P| q1_TESS        U(a = 0, b = 1)                          [    0.00 ..     1.00],
#   39 |P| q2_TESS        U(a = 0, b = 1)                          [    0.00 ..     1.00],
#   40 |P| q1_H           N(μ = 0.5, σ = 0.001)                    [    0.00 ..     1.00],
#   41 |P| q2_H           N(μ = 0.5, σ = 0.001)                    [    0.00 ..     1.00],
#   42 |P| q1_Ks          N(μ = 0.5, σ = 0.001)                    [    0.00 ..     1.00],
#   43 |P| q2_Ks          N(μ = 0.5, σ = 0.001)                    [    0.00 ..     1.00],
#   44 |P| q1_36um        N(μ = 0.03, σ = 0.0005)                  [    0.00 ..     1.00],
#   45 |P| q2_36um        N(μ = 0.28, σ = 0.004)                   [    0.00 ..     1.00],
#   46 |P| q1_45um        N(μ = 0.02, σ = 0.0004)                  [    0.00 ..     1.00],
#   47 |P| q2_45um        N(μ = 0.29, σ = 0.005)                   [    0.00 ..     1.00],
#   48 |L| gp_ln_out      N(μ = -6.0, σ = 1.5)                     [    -inf ..      inf],
#   49 |L| gp_ln_in       U(a = -8, b = 8)                         [    -inf ..      inf],
#   50 |L| gp_log10_wn    N(μ = -2.91843678487546, σ = 0.025)      [    -inf ..      inf],
#   51 |L| gp_ln_out      N(μ = -6.0, σ = 1.5)                     [    -inf ..      inf],
#   52 |L| gp_ln_in       U(a = -8, b = 8)                         [    -inf ..      inf],
#   53 |L| gp_log10_wn    N(μ = -3.33285232617357, σ = 0.025)      [    -inf ..      inf],
#   54 |L| gp_ln_out      N(μ = -6.0, σ = 1.5)                     [    -inf ..      inf],
#   55 |L| gp_ln_in       U(a = -8, b = 8)                         [    -inf ..      inf],
#   56 |L| gp_log10_wn    N(μ = -3.269937474000881, σ = 0.025)     [    -inf ..      inf],
#   57 |L| wn_loge_3      U(a = -4, b = 0)                         [    -inf ..      inf],
#   58 |L| wn_loge_4      U(a = -4, b = 0)                         [    -inf ..      inf],
#   59 |L| wn_loge_5      U(a = -4, b = 0)                         [    -inf ..      inf],
#   60 |L| wn_loge_6      U(a = -4, b = 0)                         [    -inf ..      inf],
#   61 |L| lm_i__0        N(μ = 1.0, σ = 0.002276041968930984)     [    -inf ..      inf],
#   62 |L| lm_i__0        N(μ = 1.0, σ = 0.000931677930784044)     [    -inf ..      inf],
#   63 |L| lm_s__0_1      N(μ = 0.0, σ = 0.000931677930784044)     [    -inf ..      inf],
#   64 |L| lm_s__0_2      N(μ = 0.0, σ = 0.000931677930784044)     [    -inf ..      inf],
#   65 |L| lm_s__0_3      N(μ = 0.0, σ = 0.000931677930784044)     [    -inf ..      inf],
#   66 |L| lm_s__0_4      N(μ = 0.0, σ = 0.000931677930784044)     [    -inf ..      inf],
#   67 |L| lm_s__0_5      N(μ = 0.0, σ = 0.000931677930784044)     [    -inf ..      inf],
#   68 |L| lm_s__0_6      N(μ = 0.0, σ = 0.000931677930784044)     [    -inf ..      inf],
#   69 |L| lm_s__0_7      N(μ = 0.0, σ = 0.000931677930784044)     [    -inf ..      inf],
#   70 |L| lm_i__0        N(μ = 1.0, σ = 0.001009079094852436)     [    -inf ..      inf],
#   71 |L| lm_s__0_1      N(μ = 0.0, σ = 0.001009079094852436)     [    -inf ..      inf],
#   72 |L| lm_s__0_2      N(μ = 0.0, σ = 0.001009079094852436)     [    -inf ..      inf],
#   73 |L| lm_i__0        N(μ = 1.0, σ = 0.004036775044459743)     [    -inf ..      inf],
#   74 |L| lm_s__0_1      N(μ = 0.0, σ = 0.004036775044459743)     [    -inf ..      inf],
#   75 |L| lm_s__0_2      N(μ = 0.0, σ = 0.004036775044459743)     [    -inf ..      inf],
#   76 |L| lm_s__0_3      N(μ = 0.0, σ = 0.004036775044459743)     [    -inf ..      inf],
#   77 |L| lm_s__0_4      N(μ = 0.0, σ = 0.004036775044459743)     [    -inf ..      inf],
#   78 |L| lm_s__0_5      N(μ = 0.0, σ = 0.004036775044459743)     [    -inf ..      inf],
#   79 |L| lm_s__0_6      N(μ = 0.0, σ = 0.004036775044459743)     [    -inf ..      inf],
#   80 |L| lm_i__0        N(μ = 1.0, σ = 0.00765465143417929)      [    -inf ..      inf],
#   81 |L| lm_s__0_1      N(μ = 0.0, σ = 0.00765465143417929)      [    -inf ..      inf],
#   82 |L| lm_s__0_2      N(μ = 0.0, σ = 0.00765465143417929)      [    -inf ..      inf],
#   83 |L| lm_s__0_3      N(μ = 0.0, σ = 0.00765465143417929)      [    -inf ..      inf],
#   84 |L| lm_s__0_4      N(μ = 0.0, σ = 0.00765465143417929)      [    -inf ..      inf],
#   85 |L| lm_s__0_5      N(μ = 0.0, σ = 0.00765465143417929)      [    -inf ..      inf],
#   86 |L| lm_s__0_6      N(μ = 0.0, σ = 0.00765465143417929)      [    -inf ..      inf],
#   87 |L| lm_i__0        N(μ = 1.0, σ = 0.005941674550509351)     [    -inf ..      inf],
#   88 |L| lm_s__0_1      N(μ = 0.0, σ = 0.005941674550509351)     [    -inf ..      inf],
#   89 |L| lm_s__0_2      N(μ = 0.0, σ = 0.005941674550509351)     [    -inf ..      inf],
#   90 |L| lm_s__0_3      N(μ = 0.0, σ = 0.005941674550509351)     [    -inf ..      inf],
#   91 |L| lm_s__0_4      N(μ = 0.0, σ = 0.005941674550509351)     [    -inf ..      inf],
#   92 |L| lm_s__0_5      N(μ = 0.0, σ = 0.005941674550509351)     [    -inf ..      inf],
#   93 |L| lm_s__0_6      N(μ = 0.0, σ = 0.005941674550509351)     [    -inf ..      inf],
#   94 |L| lm_i__0        N(μ = 1.0, σ = 0.00463721715595512)      [    -inf ..      inf],
#   95 |L| lm_s__0_1      N(μ = 0.0, σ = 0.00463721715595512)      [    -inf ..      inf],
#   96 |L| lm_s__0_2      N(μ = 0.0, σ = 0.00463721715595512)      [    -inf ..      inf],
#   97 |L| lm_s__0_3      N(μ = 0.0, σ = 0.00463721715595512)      [    -inf ..      inf],
#   98 |L| lm_s__0_4      N(μ = 0.0, σ = 0.00463721715595512)      [    -inf ..      inf],
#   99 |L| lm_s__0_5      N(μ = 0.0, σ = 0.00463721715595512)      [    -inf ..      inf],
#  100 |L| lm_s__0_6      N(μ = 0.0, σ = 0.00463721715595512)      [    -inf ..      inf],
#  101 |L| lm_i__0        N(μ = 1.0, σ = 0.0019422680513457738)    [    -inf ..      inf],
#  102 |L| lm_s__0_1      N(μ = 0.0, σ = 0.0019422680513457738)    [    -inf ..      inf],
#  103 |L| lm_s__0_2      N(μ = 0.0, σ = 0.0019422680513457738)    [    -inf ..      inf],
#  104 |L| lm_s__0_3      N(μ = 0.0, σ = 0.0019422680513457738)    [    -inf ..      inf],
#  105 |L| lm_s__0_4      N(μ = 0.0, σ = 0.0019422680513457738)    [    -inf ..      inf],
#  106 |L| lm_s__0_5      N(μ = 0.0, σ = 0.0019422680513457738)    [    -inf ..      inf],
#  107 |L| lm_s__0_6      N(μ = 0.0, σ = 0.0019422680513457738)    [    -inf ..      inf],
#  108 |L| lm_i__0        N(μ = 1.0, σ = 0.0017005028549136603)    [    -inf ..      inf],
#  109 |L| lm_s__0_1      N(μ = 0.0, σ = 0.0017005028549136603)    [    -inf ..      inf],
#  110 |L| lm_s__0_2      N(μ = 0.0, σ = 0.0017005028549136603)    [    -inf ..      inf],
#  111 |L| lm_s__0_3      N(μ = 0.0, σ = 0.0017005028549136603)    [    -inf ..      inf],
#  112 |L| lm_s__0_4      N(μ = 0.0, σ = 0.0017005028549136603)    [    -inf ..      inf],
#  113 |L| lm_s__0_5      N(μ = 0.0, σ = 0.0017005028549136603)    [    -inf ..      inf],
#  114 |L| lm_s__0_6      N(μ = 0.0, σ = 0.0017005028549136603)    [    -inf ..      inf],
#  115 |L| lm_i__0        N(μ = 1.0, σ = 0.002825442557144759)     [    -inf ..      inf],
#  116 |L| lm_s__0_1      N(μ = 0.0, σ = 0.002825442557144759)     [    -inf ..      inf],
#  117 |L| lm_s__0_2      N(μ = 0.0, σ = 0.002825442557144759)     [    -inf ..      inf],
#  118 |L| lm_s__0_3      N(μ = 0.0, σ = 0.002825442557144759)     [    -inf ..      inf],
#  119 |L| lm_s__0_4      N(μ = 0.0, σ = 0.002825442557144759)     [    -inf ..      inf],
#  120 |L| lm_s__0_5      N(μ = 0.0, σ = 0.002825442557144759)     [    -inf ..      inf],
#  121 |L| lm_s__0_6      N(μ = 0.0, σ = 0.002825442557144759)     [    -inf ..      inf],
#  122 |L| lm_i__0        N(μ = 1.0, σ = 0.0015744839087324732)    [    -inf ..      inf],
#  123 |L| lm_s__0_1      N(μ = 0.0, σ = 0.0015744839087324732)    [    -inf ..      inf],
#  124 |L| lm_s__0_2      N(μ = 0.0, σ = 0.0015744839087324732)    [    -inf ..      inf],
#  125 |L| lm_s__0_3      N(μ = 0.0, σ = 0.0015744839087324732)    [    -inf ..      inf],
#  126 |L| lm_s__0_4      N(μ = 0.0, σ = 0.0015744839087324732)    [    -inf ..      inf],
#  127 |L| lm_s__0_5      N(μ = 0.0, σ = 0.0015744839087324732)    [    -inf ..      inf],
#  128 |L| lm_s__0_6      N(μ = 0.0, σ = 0.0015744839087324732)    [    -inf ..      inf]]

# %%
corner(df.iloc[:,[0,1,2,3,6,7]]);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
corner(df.iloc[:,8:14]);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
corner(df.iloc[:,14:20]);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
corner(df.iloc[:,20:26]);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
corner(df.iloc[:,26:32]);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %%
corner(df.iloc[:,32:38]);
# Out:
# WARNING:root:Pandas support in corner is deprecated; use ArviZ directly

# %% [markdown]
# ---
#
# <center>&copy 2021 Hannu Parviainen</center>
